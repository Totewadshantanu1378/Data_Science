# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("placement.csv")
df = df.drop(df.columns[:1] , axis = 1)
df = df.iloc[:,:-1]
df
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
x = df[['cgpa']]
y = df['iq']

# %%
sns.scatterplot(x = "cgpa",y = "iq" , data = df )
# Out:
# <Axes: xlabel='cgpa', ylabel='iq'>

# %%
from sklearn.model_selection import train_test_split
xtrain ,xtest , ytrain , ytest  = train_test_split(x, y, test_size = 0.2 , random_state = 42)

# %%
from sklearn.svm import SVR

# %%
sv = SVR(kernel = "rbf")
sv.fit(xtrain , ytrain )

# the dataset is not suitable thats why showing the minute accuracy iin negative
# Out:
# SVR()

# %%
sv.score(xtest , ytest)*100
# Out:
# -12.932073653268205

# %%
sns.scatterplot(x = "cgpa" ,y = "iq" , data = df)
plt.plot(x, sv.predict(x) , color = "red")

# to inaccurate due to unsuitable dataset
