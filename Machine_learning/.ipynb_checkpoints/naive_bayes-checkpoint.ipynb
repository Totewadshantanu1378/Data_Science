# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("placement.csv")
df
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [100 rows x 4 columns]

# %%
df.isnull().sum()
#no null values present
# Out:
# Unnamed: 0    0
# cgpa          0
# iq            0
# placement     0
# dtype: int64

# %%
# lets analyze the graph so that we can understand whether it is linearly seperrable or not
plt.figure(figsize=(4,3))
sns.scatterplot(x = "cgpa" , y = "iq",data = df , hue = "placement" )
# Out:
# <Axes: xlabel='cgpa', ylabel='iq'>

# %%
sns.kdeplot(data = df['cgpa'])
# Out:
# <Axes: xlabel='cgpa', ylabel='Density'>

# %%
x = df[['cgpa' , 'iq']]
y = df['placement']

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain , xtest , ytrain , ytest = train_test_split(x , y , test_size=0.2, random_state=42)

# %%
from sklearn.naive_bayes import GaussianNB , MultinomialNB , BernoulliNB

# %%
gnb = GaussianNB()
gnb.fit(xtrain , ytrain)
# Out:
# GaussianNB()

# %%
gnb.score(xtest , ytest)*100
# Out:
# 85.0

# %%
mnb = MultinomialNB()
mnb.fit(xtrain , ytrain)
# Out:
# MultinomialNB()

# %%
mnb.score(xtest , ytest)*100
# Out:
# 95.0

# %%
bnb = BernoulliNB()
bnb.fit(xtrain , ytrain)
# Out:
# BernoulliNB()

# %%
bnb.score(xtest , ytest)*100
# Out:
# 50.0

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x.to_numpy() ,y.to_numpy(), clf=gnb)
# Out:
# C:\Users\shant\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(
# <Axes: >

# %%
plot_decision_regions(x.to_numpy() ,y.to_numpy(), clf=mnb)
# Out:
# C:\Users\shant\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but MultinomialNB was fitted with feature names
#   warnings.warn(
# <Axes: >

# %%
plot_decision_regions(x.to_numpy() ,y.to_numpy(), clf=bnb)  
# here x should contains exacly 2 features so that it can be classified 
# it has 50 - 50 chances so no decision boundary appeared
# Out:
# C:\Users\shant\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but BernoulliNB was fitted with feature names
#   warnings.warn(
# <Axes: >
