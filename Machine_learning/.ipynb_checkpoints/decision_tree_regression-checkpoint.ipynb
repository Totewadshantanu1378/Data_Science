# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("multiple_linear_regression_dataset.csv")
df.head()
# Out:
#    age  experience  income
# 0   25           1   30450
# 1   30           3   35670
# 2   47           2   31580
# 3   32           5   40130
# 4   43          10   47830

# %%
df.isnull().sum()
# Out:
# age           0
# experience    0
# income        0
# dtype: int64

# %%
sns.pairplot(data = df)

# %%
x = df.iloc[:,:-1]
y = df['experience']

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain ,xtest , ytrain , ytest = train_test_split(x , y ,test_size=0.2, random_state=42)

# %%
from sklearn.tree import DecisionTreeRegressor , plot_tree

# %%
# for i in range(1 , 100):
#     dt = DecisionTreeRegressor(max_depth=i)
#     dt.fit(xtrain ,ytrain)
#     # print(dt.score(xtest,ytest) , dt.score(xtrain , ytrain) , i)
#     # so at maximum depth - 5 we get good fitting
dt = DecisionTreeRegressor(max_depth=10)
# in regressor there is no any criteria like gini index or entrpy , there are meansqaured error , mean absolute error present in regressor

# %%
 dt.fit(xtrain,ytrain)
# Out:
# DecisionTreeRegressor(max_depth=10)

# %%
dt.score(xtest , ytest)
# Out:
# 0.7014925373134329

# %%
 dt.score(xtrain,ytrain)
# Out:
# 1.0

# %%
plot_tree(dt)
plt.plot()
# Out:
# []
